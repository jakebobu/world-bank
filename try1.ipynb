# %%
import pandas as pd

# %%
wdi_df = pd.read_csv('/home/jake/world-bank/data_sheets/WDIData.csv')
ed_df = pd.read_csv('/home/jake/world-bank/data_sheets/EdStatsData.csv')
gender_df = pd.read_csv('/home/jake/world-bank/data_sheets/Gender_StatsData.csv')
hnp_df = pd.read_csv('/home/jake/world-bank/data_sheets/HNP_StatsData.csv')
ids_df = pd.read_csv('/home/jake/world-bank/data_sheets/IDSData.csv')
pov_df = pd.read_csv('/home/jake/world-bank/data_sheets/PovStatsData.csv')
sdg_df = pd.read_csv('/home/jake/world-bank/data_sheets/SDGData.csv')

# %%
ed_df = pd.read_csv('/home/jake/world-bank/data_sheets/EdStatsData.csv')
ed_df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
#        '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
#        '2095', '2100', 'Unnamed: 69'],
#       dtype='object')

# %%
mask1= wdi_df['Country Name'].isin(['Paraguay','Fiji'])
mask2=wdi_df['Indicator Name'].isin(['Age dependency ratio, young (% of working-age population)','Urban population'])
wdi_df=wdi_df[mask1]
wdi_df=wdi_df[mask2]
wdi_df[['2016','1960']]
# Out:
# /home/jake/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#                 2016           1960
# 176351  4.373838e+01      97.557321
# 177833  4.862200e+05  116761.000000
# 313289  4.637727e+01      97.976499
# 314771  4.030074e+06  676834.000000

# %%
mask1= wdi_df['Country Name'].isin(['Morocco','Andorra'])
mask2=wdi_df['Indicator Name'].isin(['Net bilateral aid flows from DAC donors, Total (current US$)','Adjusted savings: education expenditure (% of GNI)'])
wdi_df=wdi_df[mask1]
wdi_df=wdi_df[mask2]
wdi_df[['2001','1993']]
# Out:
# /home/jake/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#                 2001         1993
# 80315   2.265714e+00          3.3
# 81173            NaN          NaN
# 283361  5.300000e+00          5.3
# 284219  4.742100e+08  629330000.0

# %%
out=wdi_df.loc[80315][['Country Name','Indicator Name','2001']]
out
# Out:
# Country Name                                                Andorra
# Indicator Name    Adjusted savings: education expenditure (% of ...
# 2001                                                        2.26571
# Name: 80315, dtype: object

# %%
wdi_df[wdi_df['Country Name']=='Morocco' AND wdi_df['Indicator Name']=='Net bilateral aid flows from DAC donors, Total (current US$)'][['Indicator Name','1993']]
# Out:
#   File "<ipython-input-9-e3c4d743e2b9>", line 1
#     wdi_df[wdi_df['Country Name']=='Morocco' AND wdi_df['Indicator Name']=='Net bilateral aid flows from DAC donors, Total (current US$)'][['Indicator Name','1993']]
#                                                ^
# SyntaxError: invalid syntax

# %%
wdi_df.pivot(index='Country Code', columns='Indicator Code').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 264 entries, ABW to ZWE
# Columns: 96014 entries, (Country Name, AG.AGR.TRAC.NO) to (Unnamed: 62, per_si_allsi.cov_q5_tot)
# dtypes: float64(92866), object(3148)
# memory usage: 193.4+ MB

# %%
piv_df=wdi_df.pivot(index='Country Code', columns='Indicator Code')

# %%
piv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 264 entries, ABW to ZWE
# Columns: 96014 entries, (Country Name, AG.AGR.TRAC.NO) to (Unnamed: 62, per_si_allsi.cov_q5_tot)
# dtypes: float64(92866), object(3148)
# memory usage: 193.4+ MB

# %%
piv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 264 entries, ABW to ZWE
# Columns: 96014 entries, (Country Name, AG.AGR.TRAC.NO) to (Unnamed: 62, per_si_allsi.cov_q5_tot)
# dtypes: float64(92866), object(3148)
# memory usage: 193.4+ MB

# %%
for df in [wdi_df,ed_df,gender_df,hnp_df,ids_df,pov_df,sdg_df]:
    print(df[df.count(axis=1).values>(len(df.columns)-4)].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35468 entries, 55 to 415509
# Data columns (total 63 columns):
# Country Name      35468 non-null object
# Country Code      35468 non-null object
# Indicator Name    35468 non-null object
# Indicator Code    35468 non-null object
# 1960              32690 non-null float64
# 1961              35422 non-null float64
# 1962              35434 non-null float64
# 1963              35457 non-null float64
# 1964              35462 non-null float64
# 1965              35460 non-null float64
# 1966              35400 non-null float64
# 1967              35460 non-null float64
# 1968              35466 non-null float64
# 1969              35465 non-null float64
# 1970              35456 non-null float64
# 1971              35458 non-null float64
# 1972              35467 non-null float64
# 1973              35467 non-null float64
# 1974              35465 non-null float64
# 1975              35465 non-null float64
# ...

# %%
wdi_df[wdi_df.count(axis=1).values>(len(wdi_df.columns)-4)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35468 entries, 55 to 415509
# Data columns (total 63 columns):
# Country Name      35468 non-null object
# Country Code      35468 non-null object
# Indicator Name    35468 non-null object
# Indicator Code    35468 non-null object
# 1960              32690 non-null float64
# 1961              35422 non-null float64
# 1962              35434 non-null float64
# 1963              35457 non-null float64
# 1964              35462 non-null float64
# 1965              35460 non-null float64
# 1966              35400 non-null float64
# 1967              35460 non-null float64
# 1968              35466 non-null float64
# 1969              35465 non-null float64
# 1970              35456 non-null float64
# 1971              35458 non-null float64
# 1972              35467 non-null float64
# 1973              35467 non-null float64
# 1974              35465 non-null float64
# 1975              35465 non-null float64
# ...

# %%
for df in []:
# Out:
#   File "<ipython-input-8-97f0ff8f4bcc>", line 1
#     for df in []:
#                  ^
# SyntaxError: unexpected EOF while parsing

# %%
wdi_df['Country Name'].unique()

# %%
wdi_df['Indicator Name'].unique().size

# %%
wdi_df[['Country Code','Indicator Name','1960','1963','1970','1987','1992']].dropna()
# Out:
#        Country Code                                     Indicator Name  \
# 55              ARB  Adolescent fertility rate (births per 1,000 wo...
# 61              ARB  Age dependency ratio (% of working-age populat...
# 62              ARB  Age dependency ratio, old (% of working-age po...
# 63              ARB  Age dependency ratio, young (% of working-age ...
# 99              ARB               Aquaculture production (metric tons)
# 107             ARB        Arms imports (SIPRI trend indicator values)
# 141             ARB               Birth rate, crude (per 1,000 people)
# 154             ARB         Capture fisheries production (metric tons)
# 212             ARB                                 CO2 emissions (kt)
# 213             ARB             CO2 emissions (metric tons per capita)
# 215             ARB  CO2 emissions from gaseous fuel consumption (%...
# 217             ARB  CO2 emissions from liquid fuel consumption (% ...
# ...

# %%
wdi_less=wdi_df.drop(['2017','Unnamed: 62'],axis=1)

# %%
wdi_dense=wdi_less.dropna(axis=0).dropna(axis=1)
wdi_dense.head()
# Out:
#     Country Name Country Code  \
# 61    Arab World          ARB
# 62    Arab World          ARB
# 63    Arab World          ARB
# 107   Arab World          ARB
# 811   Arab World          ARB
#
#                                         Indicator Name     Indicator Code  \
# 61   Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 62   Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# 63   Age dependency ratio, young (% of working-age ...     SP.POP.DPND.YG
# 107        Arms imports (SIPRI trend indicator values)     MS.MIL.MPRT.KD
# 811                  Merchandise exports (current US$)  TX.VAL.MRCH.CD.WT
#
#              1960          1961          1962          1963          1964  \
# 61   8.820581e+01  8.964473e+01  9.094450e+01  9.206363e+01  9.289288e+01
# 62   6.602746e+00  6.714313e+00  6.809043e+00  6.884778e+00  6.937449e+00
# 63   8.146539e+01  8.277583e+01  8.394566e+01  8.492841e+01  8.563795e+01
# ...

# %%
wdi_dense['Indicator Name']
# Out:
# 61        Age dependency ratio (% of working-age populat...
# 62        Age dependency ratio, old (% of working-age po...
# 63        Age dependency ratio, young (% of working-age ...
# 107             Arms imports (SIPRI trend indicator values)
# 811                       Merchandise exports (current US$)
# 812       Merchandise exports by the reporting economy (...
# 813       Merchandise exports by the reporting economy, ...
# 814       Merchandise exports to economies in the Arab W...
# 815       Merchandise exports to high-income economies (...
# 816       Merchandise exports to low- and middle-income ...
# 817       Merchandise exports to low- and middle-income ...
# 818       Merchandise exports to low- and middle-income ...
# 819       Merchandise exports to low- and middle-income ...
# 820       Merchandise exports to low- and middle-income ...
# 821       Merchandise exports to low- and middle-income ...
# 822       Merchandise exports to low- and middle-income ...
# ...

# %%
wdi_dense['Country Code'].unique().size
# Out:
# 260

# %%
a=['Afghanistan', 'Albania', 'Algeria', 'American Samoa',
       'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia',
       'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The',
       'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
       'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
       'Bosnia and Herzegovina', 'Botswana', 'Brazil',
       'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
       'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
       'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
       'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
       'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
       'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czech Republic',
       'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador',
       'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Estonia',
       'Ethiopia', 'Faroe Islands', 'Fiji', 'Finland', 'France',
       'French Polynesia', 'Gabon', 'Gambia, The', 'Georgia', 'Germany',
       'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guam',
       'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
       'Honduras', 'Hong Kong SAR, China', 'Hungary', 'Iceland', 'India',
       'Indonesia', 'Iran, Islamic Rep.', 'Iraq', 'Ireland',
       'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan',
       'Kazakhstan', 'Kenya', 'Kiribati', 'Korea, Dem. People’s Rep.',
       'Korea, Rep.', 'Kosovo', 'Kuwait', 'Kyrgyz Republic', 'Lao PDR',
       'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya',
       'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao SAR, China',
       'Macedonia, FYR', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives',
       'Mali', 'Malta', 'Marshall Islands', 'Mauritania', 'Mauritius',
       'Mexico', 'Micronesia, Fed. Sts.', 'Moldova', 'Monaco', 'Mongolia',
       'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia',
       'Nauru', 'Nepal', 'Netherlands', 'New Caledonia', 'New Zealand',
       'Nicaragua', 'Niger', 'Nigeria', 'Northern Mariana Islands',
       'Norway', 'Oman', 'Pakistan', 'Palau', 'Panama',
       'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland',
       'Portugal', 'Puerto Rico', 'Qatar', 'Romania',
       'Russian Federation', 'Rwanda', 'Samoa', 'San Marino',
       'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Seychelles',
       'Sierra Leone', 'Singapore', 'Sint Maarten (Dutch part)',
       'Slovak Republic', 'Slovenia', 'Solomon Islands', 'Somalia',
       'South Africa', 'South Sudan', 'Spain', 'Sri Lanka',
       'St. Kitts and Nevis', 'St. Lucia', 'St. Martin (French part)',
       'St. Vincent and the Grenadines', 'Sudan', 'Suriname', 'Swaziland',
       'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Tajikistan',
       'Tanzania', 'Thailand', 'Timor-Leste', 'Togo', 'Tonga',
       'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
       'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine',
       'United Arab Emirates', 'United Kingdom', 'United States',
       'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela, RB', 'Vietnam',
       'Virgin Islands (U.S.)', 'Yemen, Rep.', 'Zambia', 'Zimbabwe']

# %%
len(a)
# Out:
# 214

# %%
b=['Afghanistan', 'Albania', 'Algeria', 'American Samoa',
       'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia',
       'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The',
       'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
       'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
       'Bosnia and Herzegovina', 'Botswana', 'Brazil',
       'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
       'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
       'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
       'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
       'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
       'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czech Republic',
       'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador',
       'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Estonia',
       'Ethiopia', 'Faroe Islands', 'Fiji', 'Finland', 'France',
       'French Polynesia', 'Gabon', 'Gambia, The', 'Georgia', 'Germany',
       'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guam',
       'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
       'Honduras', 'Hong Kong SAR, China', 'Hungary', 'Iceland', 'India',
       'Indonesia', 'Iran, Islamic Rep.', 'Iraq', 'Ireland',
       'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan',
       'Kazakhstan', 'Kenya', 'Kiribati', 'Korea, Dem. People’s Rep.',
       'Korea, Rep.', 'Kosovo', 'Kuwait', 'Kyrgyz Republic', 'Lao PDR',
       'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya',
       'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao SAR, China',
       'Macedonia, FYR', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives',
       'Mali', 'Malta', 'Marshall Islands', 'Mauritania', 'Mauritius',
       'Mexico', 'Micronesia, Fed. Sts.', 'Moldova', 'Monaco', 'Mongolia',
       'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia',
       'Nauru', 'Nepal', 'Netherlands', 'New Caledonia', 'New Zealand',
       'Nicaragua', 'Niger', 'Nigeria', 'Northern Mariana Islands',
       'Norway', 'Oman', 'Pakistan', 'Palau', 'Panama',
       'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland',
       'Portugal', 'Puerto Rico', 'Qatar', 'Romania',
       'Russian Federation', 'Rwanda', 'Samoa', 'San Marino',
       'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Seychelles',
       'Sierra Leone', 'Singapore', 'Sint Maarten (Dutch part)',
       'Slovak Republic', 'Slovenia', 'Solomon Islands', 'Somalia',
       'South Africa', 'South Sudan', 'Spain', 'Sri Lanka',
       'St. Kitts and Nevis', 'St. Lucia', 'St. Martin (French part)',
       'St. Vincent and the Grenadines', 'Sudan', 'Suriname', 'Swaziland',
       'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Tajikistan',
       'Tanzania', 'Thailand', 'Timor-Leste', 'Togo', 'Tonga',
       'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
       'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine',
       'United Arab Emirates', 'United Kingdom', 'United States',
       'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela, RB', 'Vietnam',
       'Virgin Islands (U.S.)', 'Yemen, Rep.', 'Zambia', 'Zimbabwe']

# %%
len(b)
# Out:
# 214

# %%
pd.pivot_table(wdi_dense,index=['Country Code'],columns='Indicator Code')
# Out:
#                             1960                                               \
# Indicator Code BG.GSR.NFSV.GD.ZS BM.GSR.CMCP.ZS BM.GSR.FCTY.CD BM.GSR.GNFS.CD
# Country Code
# ABW                          NaN            NaN            NaN            NaN
# AFG                          NaN            NaN            NaN            NaN
# AGO                          NaN            NaN            NaN            NaN
# ALB                          NaN            NaN            NaN            NaN
# AND                          NaN            NaN            NaN            NaN
# ARB                          NaN            NaN            NaN            NaN
# ARE                          NaN            NaN            NaN            NaN
# ARG                          NaN            NaN            NaN            NaN
# ARM                          NaN            NaN            NaN            NaN
# ASM                          NaN            NaN            NaN            NaN
# ...

# %%
wdi_dense.stack().unstack(0)
# Out:
#                                                            61      \
# Country Name                                           Arab World
# Country Code                                                  ARB
# Indicator Name  Age dependency ratio (% of working-age populat...
# Indicator Code                                        SP.POP.DPND
# 1960                                                      88.2058
# 1961                                                      89.6447
# 1962                                                      90.9445
# 1963                                                      92.0636
# 1964                                                      92.8929
# 1965                                                      93.3645
# 1966                                                      94.2418
# 1967                                                      94.6334
# 1968                                                      94.6855
# ...

# %%
wdi_df.set_index(['Country Code', 'Indicator Code']).stack().unstack(1)
